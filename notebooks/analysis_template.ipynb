# %% [markdown]
# # DAP-seq Analysis
#
# This notebook visualizes the output of the DAP-seq Snakemake pipeline.
#
# **Usage:**
# 1. Copy this notebook into your project directory (or open it directly).
# 2. Set `RESULTS_DIR` in the next cell to the path of your Snakemake output directory.
# 3. Optionally set `CONTROL` to exclude your input-control sample from plots.
# 4. Run all cells.

# %%
# ── Configuration ────────────────────────────────────────────────────────────
# Point this at the Snakemake output directory (the 'output_dir' from config.yaml)
RESULTS_DIR = "/Users/nick/Projects/Dap-Seq-pipeline/results"

# Name of the input-control sample to exclude from analysis (set to None if none)
CONTROL = None

# ── Auto-discover samples ────────────────────────────────────────────────────
from pathlib import Path

results = Path(RESULTS_DIR)
assert results.is_dir(), f"RESULTS_DIR not found: {RESULTS_DIR}"

# Samples are those with MACS summits files
all_samples = sorted(
    p.stem.replace("_summits", "")
    for p in (results / "MACS").glob("*_summits.bed")
)
samples = [s for s in all_samples if s not in [CONTROL, "TF1", "TF2"]]
print(f"Found {len(all_samples)} total samples, {len(samples)} treatment samples:")
for s in samples:
    print(f"  - {s}")

# %%
import re
import math
import base64
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from IPython.display import HTML
from matplotlib_venn import venn3
from PIL import Image, ImageOps

# %% [markdown]
# ## QC Summary

# %%
multiqc_report = results / "multiqc_report.html"
if multiqc_report.exists():
    print(f"MultiQC report: {multiqc_report}")
else:
    print("MultiQC report not found.")

# %% [markdown]
# ## Peak Calling Summary

# %%
import pysam

def parse_trimmomatic(sample):
    log = results / "logs" / "trimmomatic" / f"{sample}.log"
    if not log.exists():
        return None, None
    text = log.read_text()
    m_raw   = re.search(r'Input Read Pairs: (\d+)', text)
    m_clean = re.search(r'Both Surviving: (\d+)', text)
    return (
        int(m_raw.group(1))   if m_raw   else None,
        int(m_clean.group(1)) if m_clean else None,
    )

def get_alignment_stats(sample):
    bam = results / "bam" / f"{sample}.bam"
    if not bam.exists():
        return None, None
    stats = pysam.flagstat(str(bam))
    m_mapped = re.search(r'(\d+) \+ \d+ mapped', stats)
    m_paired = re.search(r'(\d+) \+ \d+ with itself and mate mapped', stats)
    mapped       = int(m_mapped.group(1)) if m_mapped else None
    unique_pairs = int(m_paired.group(1)) // 2 if m_paired else None
    return mapped, unique_pairs

def get_peak_stats(sample):
    peak_file = results / "MACS" / f"{sample}_peaks.narrowPeak"
    if not peak_file.exists():
        return None, None, None
    folds = [float(line.split("\t")[6]) for line in open(peak_file)]
    return (
        len(folds),
        sum(1 for f in folds if f > 5),
        round(max(folds), 4) if folds else None,
    )

def get_frip(sample, mapped_reads):
    bam_path  = results / "bam"  / f"{sample}.bam"
    peak_file = results / "MACS" / f"{sample}_peaks.narrowPeak"
    if not bam_path.exists() or not peak_file.exists() or not mapped_reads:
        return None, None
    bam = pysam.AlignmentFile(str(bam_path), "rb")
    reads_in_peaks = sum(
        bam.count(chrom, int(start), int(end))
        for line in open(peak_file)
        for chrom, start, end, *_ in [line.strip().split("\t")]
    )
    bam.close()
    return reads_in_peaks, round(100 * reads_in_peaks / mapped_reads, 2)

rows = []
for sample in samples:
    gem_file = results / "GEM" / sample / f"{sample}.GEM_events.txt"

    raw_pairs, clean_pairs          = parse_trimmomatic(sample)
    mapped, unique_pairs            = get_alignment_stats(sample)
    macs_peaks, min5fold, max_score = get_peak_stats(sample)
    gem_count  = max(0, sum(1 for _ in open(gem_file)) - 1) if gem_file.exists() else None
    peak_reads, frip                = get_frip(sample, mapped)

    mapping_pct = round(100 * mapped / (clean_pairs * 2), 2) if mapped and clean_pairs else None

    rows.append({
        "sample":              sample,
        "raw_pairs":           raw_pairs,
        "clean_pairs":         clean_pairs,
        "mapping_ratio%":      mapping_pct,
        "unique_mapped_pairs": unique_pairs,
        "MACS_peaks":          macs_peaks,
        "min5fold_peaks":      min5fold,
        "max_peak_score":      max_score,
        "GEM_peaks":           gem_count,
        "peak_reads":          peak_reads,
        "FRiP%":               frip,
    })

df_peaks = pd.DataFrame(rows)
df_peaks

# %%
df_peaks.set_index("sample")[["MACS_peaks", "GEM_peaks"]].plot(
    kind="bar", figsize=(max(6, len(samples) * 2), 5), edgecolor="black"
)
plt.ylabel("Number of Peaks")
plt.title("Peak Counts by Caller and Sample")
plt.xticks(rotation=45, ha="right")
plt.legend(["MACS2", "GEM"])
plt.tight_layout()
plt.show()

# %% [markdown]
# ## MACS2 Summit Score Distributions

# %%
fig, axes = plt.subplots(1, len(samples), figsize=(6 * len(samples), 4), squeeze=False)
axes = axes.ravel()
for ax, sample in zip(axes, samples):
    macs_file = results / "MACS" / f"{sample}_summits.bed"
    if macs_file.exists():
        df = pd.read_table(macs_file, header=None)
        scores = df[4].dropna()
        ax.hist(scores, bins=50, edgecolor="black")
        ax.set_xlabel("Summit Score (-log10 q-value)")
        ax.set_ylabel("Count")
        ax.set_title(sample)
    else:
        ax.set_title(f"{sample} (no data)")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## GEM Fold-Enrichment Distributions

# %%
fig, axes = plt.subplots(1, len(samples), figsize=(6 * len(samples), 4), squeeze=False)
axes = axes.ravel()
for ax, sample in zip(axes, samples):
    gem_file = results / "GEM" / sample / f"{sample}.GEM_events.txt"
    if gem_file.exists():
        df = pd.read_table(gem_file)
        fold = df["Fold"].dropna()
        ax.hist(fold, bins=50, edgecolor="black")
        ax.set_xlabel("IP/Control Fold Enrichment")
        ax.set_ylabel("Count")
        ax.set_title(sample)
    else:
        ax.set_title(f"{sample} (no data)")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Venn Diagrams — Peak Caller & Motif Overlap

# %%
# Compute venn sets per sample
venn_set = {}
for sample in samples:
    try:
        df_MACS      = pd.read_table(results / "compare_bed" / f"{sample}.MACS.bed", header=None)
        df_GEM       = pd.read_table(results / "compare_bed" / f"{sample}.GEM.bed", header=None)
        df_Motif     = pd.read_table(results / "fimo" / sample / "fimo.bed", header=None)
        df_MACS_peak = pd.read_table(results / "compare_bed" / f"{sample}.MACS_peak.bed", header=None)
        df_GEM_peak  = pd.read_table(results / "compare_bed" / f"{sample}.GEM_peak.bed", header=None)
        df_compare   = pd.read_table(results / "compare_bed" / f"{sample}.compare_peak.bed", header=None)

        All_overlay    = len(set(df_MACS_peak[3]).intersection(df_GEM_peak[3]))
        MACS_only      = len(df_MACS) - len(df_compare) - len(df_MACS_peak) + All_overlay
        GEM_only       = len(df_GEM) - len(df_compare) - len(df_GEM_peak) + All_overlay
        MOTIF_only     = len(df_Motif) - len(df_MACS_peak) - len(df_GEM_peak) + All_overlay
        GEM_MACS_only  = len(df_compare) - All_overlay
        MACS_MOTIF_only = len(df_MACS_peak) - All_overlay
        GEM_MOTIF_only = len(df_GEM_peak) - All_overlay

        venn_set[sample] = [MACS_only, GEM_only, GEM_MACS_only, MOTIF_only,
                            MACS_MOTIF_only, GEM_MOTIF_only, All_overlay]
    except Exception as e:
        print(f"Skipping {sample}: {e}")

print(f"Computed venn sets for {len(venn_set)}/{len(samples)} samples.")

# %%
import subprocess

def load_logo(path):
    """Load a motif logo PNG, auto-cropping whitespace."""
    img = Image.open(str(path)).convert("RGB")
    inv = ImageOps.invert(img)
    bbox = inv.getbbox()
    if bbox:
        pad = 8
        bbox = (max(0, bbox[0] - pad), max(0, bbox[1] - pad),
                min(img.width, bbox[2] + pad), min(img.height, bbox[3] + pad))
        img = img.crop(bbox)
    return np.array(img)

# Convert EPS logos to PNG for all meme output directories
for sample in list(venn_set.keys()) + [f"{s}-intersection" for s in venn_set.keys()]:
    logo_eps = results / "meme" / sample / "logo1.eps"
    logo_png = results / "meme" / sample / "logo1.png"
    if logo_eps.exists() and not logo_png.exists():
        subprocess.run(
            ["gs", "-dNOPAUSE", "-dBATCH", "-sDEVICE=png16m", "-r600",
             f"-sOutputFile={logo_png}", str(logo_eps)],
            capture_output=True
        )

# %%
def logo_html(path, width=200):
    p = Path(path)
    if not p.exists():
        return "—"
    img = load_logo(p)
    from io import BytesIO
    buf = BytesIO()
    Image.fromarray(img).save(buf, format="PNG")
    encoded = base64.b64encode(buf.getvalue()).decode()
    return f'<img src="data:image/png;base64,{encoded}" style="max-width:{width}px;">'

int_cols = ["raw_pairs", "clean_pairs", "unique_mapped_pairs",
            "MACS_peaks", "min5fold_peaks", "GEM_peaks", "peak_reads"]

df_summary = df_peaks.copy()
for col in int_cols:
    if col in df_summary:
        df_summary[col] = df_summary[col].apply(
            lambda x: f"{int(x):,}" if pd.notna(x) else "—"
        )
df_summary["motif"] = [logo_html(results / "meme" / s / "logo1.png") for s in df_summary["sample"]]

HTML(df_summary.to_html(escape=False, index=False))

# %%
# Plot venn diagrams with first-round motif logos
nrows = math.ceil(len(venn_set) / 2)
f, ax = plt.subplots(nrows, 4, figsize=(20, nrows * 5), squeeze=False)
ax = ax.ravel()
[axi.set_axis_off() for axi in ax]

for ix, sample in enumerate(venn_set):
    ax[2 * ix].set_title(sample)
    logo = results / "meme" / sample / "logo1.png"
    if logo.exists():
        ax[2 * ix].imshow(load_logo(logo))

    ax[2 * ix + 1].set_title(sample)
    venn3(subsets=venn_set[sample],
          set_labels=('MACS', 'GEM', 'Motif'), ax=ax[2 * ix + 1])

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Refined Motifs (Intersection Peaks)

# %%
# Plot venn diagrams with refined (intersection) motif logos
nrows = math.ceil(len(venn_set) / 2)
f, ax = plt.subplots(nrows, 4, figsize=(20, nrows * 5), squeeze=False)
ax = ax.ravel()
[axi.set_axis_off() for axi in ax]

for ix, sample in enumerate(venn_set):
    ax[2 * ix].set_title(sample)
    logo = results / "meme" / f"{sample}-intersection" / "logo1.png"
    if logo.exists():
        ax[2 * ix].imshow(load_logo(logo))

    ax[2 * ix + 1].set_title(sample)
    venn3(subsets=venn_set[sample],
          set_labels=('MACS', 'GEM', 'Motif'), ax=ax[2 * ix + 1])

plt.tight_layout()
plt.show()
